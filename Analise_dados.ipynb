# %% [markdown]
# <a href="https://colab.research.google.com/github/MazoelleOliveira/Analise-diversidade-2022/blob/main/Analise_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução

# %% [markdown]
# Neste notebook, exploraremos os dados coletados na pesquisa anual do Data Hackers 2022, uma das principais referências sobre o mercado de trabalho em dados e tecnologia no Brasil.
#
# A pesquisa reúne informações valiosas sobre o perfil dos profissionais da área, abordando temas como formação acadêmica, cargos, salários, tecnologias utilizadas, satisfação profissional e aspectos relacionados à diversidade e inclusão.
#
# A importância desse levantamento é significativa, pois oferece uma visão abrangente das tendências, demandas e desafios enfrentados pelos profissionais de tecnologia no país. Além disso, a pesquisa contribui para discussões relevantes sobre representatividade de gênero, raça e outros fatores que impactam a construção de um mercado mais diverso e inclusivo.
#
# Este projeto possui dois objetivos principais:
#
# 1. Praticar técnicas de análise de dados com Python, utilizando bibliotecas como pandas, matplotlib e seaborn.
# 2. Extrair insights sobre o mercado de trabalho em dados no Brasil, identificando padrões, tendências e possíveis correlações entre as variáveis disponíveis.
#
# Ao longo desta análise, serão aplicadas etapas fundamentais de um projeto de dados, como carregamento, exploração, limpeza, visualização e interpretação dos dados. Dessa forma, além de desenvolver habilidades técnicas, também será possível compreender melhor o cenário atual da área de dados no Brasil.

# %% [markdown]
# # Importações

# %%
#importações
from google.colab import drive
import pandas as pd

# %% [markdown]
# # Uso da Biblioteca Pandas

# %% [markdown]
# Modulo 3 - Primeira Análise - Uso da Biblioteca de Python(pandas) -lendo e entendendo nossos dados

# %% [markdown]
# Ei Astronautas, agora chegamos na parte mais legal do nosso curso: aprendendo Pandas🐼
#
#
#
# O pandas é a biblioteca que mais utilizamos no nosso dia-a-dia como analistas de dados, ela é super poderosa e permite a execução de diversos tipos de análise, além de se integrar com outras bibliotecas para visualizações de dados e até, um spoiler, SQL que veremos no próximo módulo ;)
#
#
#
# 📌Ah! Na nossa aula chamamos a nossa tabela de “dados”, mas é muito comum usarmos o termo “dataframe”, resumido em boa parte dos códigos como “df”.
#
#
#
# Nessa aula aprendendo as funções básicas no pandas para:
#
#
#
# ➡️Leia os arquivos: usamos o  read_excel , mas pensamos também em usar o  read_csv , caso esse fosse o formato do nosso arquivo, ou  read_json . Ou seja, o pandas permite ler diferentes formatos de arquivo.
#
# ➡️Espiar nossos dados: temos as  funções head e tail , em que podemos visualizar as primeiras e últimas linhas de nossa tabela respectivamente.
#
# ➡️Ver a dimensão dos nossos dados: temos a  função len , que nos mostra a quantidade de linhas que temos e a  função shape , que mostra a quantidade de linhas e de colunas que temos.
#
# ➡️Ter informações sobre os nossos dados: temos a  função columns , que nos diz quais são nossas colunas, a  função info  que nos mostra os índices, as colunas, o total de dados, a quantidade de cada tipo de dado, que nesse caso chamamos de dtypes, o quanto de cada variável são de valores não nulos (entenderemos melhor esse conceito mais à frente), e a memória que a nossa tabela está ocupando. E a  função describe, que nos dá informações sobre as variáveis numéricas, valores máximos e mínimos, média, desvio, mediana (também veremos esses conceitos mais a frente).

# %%
from google.colab import drive

# %%
# Montando o drive
# Etapa de processamento dos dados
drive.mount ('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Lendo os dados
# Cria ou atualiza uma variável
dados = pd.read_excel('/content/drive/MyDrive/Materiais e arquivos/Materiais importantes /Curso Programaria /Arquivos /planilha_modulo3.xlsx')#aqui eu guardei dentro de uma variavel

# %%
#Importa função ou módulo específico
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#usando a funcao head- para vermos as 5 primeiras linhas
# Exibe as primeiras linhas da tabela
dados.head(5)
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
# ...

# %%
#usando a função head - para vermos as 10 primeiras linhas:
# Exibe as primeiras linhas da tabela
dados.head(10)
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5           5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6           6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 7           7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34   Feminino
# 8           8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj   33.0       30-34  Masculino
# 9           9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
#função para vermos as linhas finais - o padrão é vermos as últimas 5 linhas:
# Etapa de processamento dos dados
dados.tail()
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4269        4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 4266  Masculino         Branca  Não
# 4267   Feminino         Branca  Não
# 4268  Masculino         Branca  Não
# 4269  Masculino         Branca  Não
# 4270  Masculino         Branca  Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA ASPECTOS_PREJUDICADOS  \
# 4266                                                NaN                   NaN
# 4267  Não acredito que minha experiência profissiona...                   NaN
# 4268                                                NaN                   NaN
# ...

# %%
# para vermos o tamanho da planinha, use shape
# Etapa de processamento dos dados
dados.shape
# Out:
# (4271, 28)

# %%
#outra forma, usando a função Len()
# Etapa de processamento dos dados
len(dados)
# Out:
# 4271

# %%
#verificando os atributos da tabela
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
#função info, para verificarmos tudo da tabela, inclusive os tipos de dados:
# Mostra informações gerais do DataFrame
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %%
#descrição, da um dá um retorno das colunas com valores numéricos, repare que não vão aparecer todas as colunas justamente por esse motivo:
dados.describe()
# Out:
#         Unnamed: 0        IDADE  MUDOU DE ESTADO?      GESTOR?        SALARIO
# count  4271.000000  4197.000000       4171.000000  3694.000000    3694.000000
# mean   2135.000000    31.169168          0.806281     0.193016   10969.266919
# std    1233.075829     6.902803          0.395258     0.394719   19419.753189
# min       0.000000    18.000000          0.000000     0.000000      35.000000
# 25%    1067.500000    26.000000          1.000000     0.000000    4269.500000
# 50%    2135.000000    30.000000          1.000000     0.000000    7625.500000
# 75%    3202.500000    35.000000          1.000000     0.000000   12778.500000
# max    4270.000000    54.000000          1.000000     1.000000  485191.000000

# %% [markdown]
# #Repetindo análise do excel

# %% [markdown]
# 3.5 - Repetindo a primeira Análise ( parte 1)

# %% [markdown]
# Ei, Astronautas. Tudo certo por aí?🥰
#
#
#
# Repetimos a análise que fizemos lá no Google Planilhas, lembra? Nessa primeira parte aprender filtros, agrupamentos, contagens.
#
# Vamos verificar cada uma dessas funções:
#
#
#
# Filtros:
#
#
#
# ➡️O Pandas permite filtrar dados de forma prática, colocamos os critérios dentro dos colchetes do uso de colchetes e a comparação de valores. Exemplo:   df[df['idade']>18]  estamos filtrando nos dados dentro do df todos os registros em que o campo idade está preenchido com valores maiores que 18.
#
#
#
# ➡️É possível filtrar por igualdade (  ==  ), diferença (  !=  ), contém (  str.contains()  ) e valores numéricos (  >  ).
#
#
#
# ➡️Múltiplos filtros podem ser combinados com os operadores   &   (e) e   |   (ou).
#
#
#
# Agrupamentos e Contagens:
#
#
#
# ➡️A função   nunique()   conta o número de valores únicos em cada grupo. Ex.:   df['nome'].nunique()  contém o número de nomes únicos nos dados que estão em df
#
#
#
# ➡️A função   groupby   agrupa dados por uma coluna específica. Ex.:   df.groupby('Estado')['morador'].nunique()  agrupamos por Estado e contamos a quantidade de moradores únicos em cada Estado.
#
#
#
# ➡️A função   value_counts()   conta quantas ocorrências temos de cada valor presente nas colunas passadas. Ex:   df['Estado'].value_counts()   mostrará quantas vezes cada Estado aparece dentro do df
#
# Ah, nessa parte também vimos o parâmetro dropna, se colocarmos ele igual a False teremos a contagem dos Nulos também.
#
#
#
# Bom, são funções bem úteis né? Mais importante do que aprender a escrever a função, é saber usá-la quando precisarmos para facilitar nossa análise! Lembre-se de manter um olhar crítico sobre os dados e usar essas funções para descobrir as respostas que precisamos🤗
#
#
#
# ✨Cenas dos próximos capítulos✨
#
#
#
# Na próxima aula teremos:
#
#
#
# ➡️Continuação desta aula onde aprenderemos a função de pivot_table!

# %%
 #Etapa de processamento dos dados
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
# Etapa de processamento dos dados
dados['GENERO']
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %%
 #aqui eu puxei todos que sao femininos
 # Etapa de processamento dos dados
dados[dados['GENERO']=='Feminino']
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# ...

# %%
#Cria ou atualiza uma variável
dados[dados['GENERO']!= "Masculino"] # diferente de masculino
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# ...

# %%
#não é nulo, com a função contains foi possivel filtrar todos os valores que continham o não, como prefiro nao informar mesmo nem sabendo dessa informação na tabela
dados[dados['GENERO'].str.contains('não', na=False)]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 562          562  vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528        1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913        1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925        1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554        2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090        3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357        3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493        3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610        3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171        4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200        4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227        4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
# ...

# %%
# Cria ou atualiza uma variável
dados[dados['IDADE']>=30]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# ...          ...                               ...    ...         ...
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
# 4264        4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %% [markdown]
# 3.5 - Repetindo a primeira análise (parte2)

# %% [markdown]
# Continuando com a nossa análise, agora vimos como reproduzir as tabelas cruzadas/dinâmicas, que fizemos no excel, no pandas. E para isso funciona a função      pivot_table     .
#
#
#
# ➡️A     função pivot_table     cria tabelas dinâmicas no Pandas.
#
# Ela recebe como parâmetros a tabela e “pivota”/transforma a tabela cruzando as linhas e colunas passadas com a função de agregação escolhida. É uma ferramenta muito útil em várias situações para simplificar os dados e facilitar a análise.
#
#
#
# Exemplo:
#
# pd.pivot_table(df,index=["Vendedor"],values=["Preço"],columns=["Tipo de Produto"],aggfunc=[np.sum])
#
# Estamos cruzando os vendedores com tipo de produto para descobrirmos as vendas totais de cada vendedor por tipo de produto.
#
# ➡️Podemos obter o mesmo resultado usando também a    função crosstab.
#
#
#
# Exemplo:
#
# pd.crosstab(df['Vendedor'], df['Tipo de Produto'], valores=df[Preço], aggfunc='sum')
#
#
#
# Legal, né🤩 Vimos nestas duas aulas poucas coisas podemos fazer com funções simples que já acrescentamos muito em nossa análise. Existem várias maneiras de obter o mesmo resultado em pandas🐼

# %%
#idade > 30 e genero feminino
# Etapa de processamento dos dados
dados[(dados['IDADE']>30) & (dados[ 'GENERO'] == 'Feminino')]  #idade > 30 e genero feminino
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 14            14  zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39
# 23            23  zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49
# ...          ...                               ...    ...         ...
# 4214        4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44
# 4221        4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34
# 4240        4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39
# 4247        4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
#
#         GENERO COR/RACA/ETNIA                   PCD  \
# 4     Feminino         Branca                   Não
# ...

# %%
# Etapa de processamento dos dados
dados[(dados['COR/RACA/ETNIA']=='Amarela') & (dados['IDADE']>40) &(dados[ 'GENERO'] == 'Feminino')]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 492          492  w4ld9w5goe7503cq3jqfw4ld9wj49ma1   43.0       40-44
# 590          590  v9cagsq6dcf02v9clwn23i01yohn9lwn   43.0       40-44
# 968          968  ryw41mfv3pq2whtfmjwryw41mlzp7yh6   43.0       40-44
# 1454        1454  nmthv38tklvb6hnmttu3qt1r4ypirgir   48.0       45-49
# 1775        1775  l8kzte32kzgceu5g9y2l8kztbh07xoh5   48.0       45-49
# 2720        2720  dn7orffcmwqb02parydn7ornhsn3ozw3   41.0       40-44
# 3430        3430  74cjlx5nshxd1b8j74cjdj3riupn8d2t   53.0       50-54
# 3888        3888  3blmjy8xbn0qxt2543busm73t10e19qm   41.0       40-44
# 4076        4076  1lwfy38bx9ogrw8ik91lwfyal0tikxld   49.0       45-49
# 4210        4210  0hbwm1d1wz739r40hbwm1df6ky5kn4ap   43.0       40-44
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 492   Feminino        Amarela  Não
# 590   Feminino        Amarela  Não
# 968   Feminino        Amarela  Não
# 1454  Feminino        Amarela  Não
# ...

# %%
# Agrupa os dados para análise
dados.groupby('GENERO')['ID'].nunique ()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
# Remove valores nulos da base
dados.groupby('GENERO', dropna= False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
# Remove valores nulos da base
dados['GENERO'].value_counts(dropna=False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %%
# Conta frequência dos valores
dados[dados['IDADE']>30]['NIVEL'].value_counts()
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
# Conta frequência dos valores
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]['NIVEL'].value_counts()
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %%
# Cria ou atualiza uma variável
pd.pivot_table(dados,values =['ID'],index=['GENERO'],columns=['GESTOR?'],aggfunc='count')
# Out:
#                         ID
# GESTOR?                0.0  1.0
# GENERO
# Feminino               754  132
# Masculino             2212  578
# Prefiro não informar     9    2

# %% [markdown]
# # Módulo 4 -Estatística Básica

# %% [markdown]
# Ei, Astronautas👩🏽‍🚀 Esta foi uma aula super importante em que aprendemos conceitos básicos de estatística. Independente se fazemos isso em python, excel ou até num papel, é muito importante entendermos esses conceitos para tomar decisões em dados de forma correta, aplicando e entendendo a diferença entre média e mediana, por exemplo😊
#
# Os conceitos que vimos foram:
#
# ➡️Média: Representa o valor central dos dados. É calculada pela soma de todos os valores e divisão pela quantidade de valores.
#
# A função np.mean() é utilizada para calcular a média em listas do NumPy.
#
# A função dados["IDADE"].mean() calcula a média da coluna "IDADE" no Pandas.
#
# Podemos calcular também a média ponderada, em que cada valor tem um peso diferente. Por exemplo, vamos imaginar que estamos fazendo uma votação para definir o preço de um produto em uma empresa, mas os votos dos diretores da empresa têm um peso maior. Então para isso temos uma coluna com os pesos dos votos e outra com o preço. O cálculo da média ponderada fica assim:
#
# media_ponderada = (df[Preco] * df['Pesos']).sum() / df['Pesos'].sum()
#
#
#
# ➡️Mediana: Valor central dos dados ordenados. Menos afetada por valores extremos ("outliers").
#
# A função np.median() calcula a mediana em listas do NumPy.
#
# A função dados["IDADE"].median() calcula a mediana da coluna "IDADE" no Pandas.
#
#
#
# ➡️Moda: Valor que aparece mais frequentemente nos dados.
#
# A função dados["IDADE"].mode() calcula a moda da coluna "IDADE" no Pandas.
#
#
#
# ➡️Desvio Padrão: Mede a dispersão dos dados em relação à média.
#
# A função dados["IDADE"].std() calcula o desvio padrão da coluna "IDADE" no Pandas.
#
#
#
# ➡️Min e Max: Retornam o menor e o maior valor da coluna, respectivamente.
#
# A função dados["IDADE"].min() retorna o valor mínimo da coluna "IDADE" no Pandas.
#
# A função dados["IDADE"].max() retorna o valor máximo da coluna "IDADE" no Pandas.

# %%
# Importa biblioteca utilizada no projeto
import numpy as np

# %%
# Cria ou atualiza uma variável
lista_idades =[26, 30, 32, 22, 26, 35, 40,20,43,31,23]

# %%
##vamos extrair a média, usando o SUM pra somar a lista e depois vendo a quantidade de linhas pra poder dividir:
np.sum(lista_idades)
# Out:
# np.int64(328)

# %%
 #quantidade de idades
 # Etapa de processamento dos dados
len(lista_idades)
# Out:
# 11

# %%
#agora sim, vamos extrair a média, usando o SUM pra somar a lista:
# Realiza soma dos valores
np.sum(lista_idades)/len(lista_idades)
# Out:
# np.float64(29.818181818181817)

# %%
#temos um função numpy pra calcular a média também, veja:
# Calcula média
media =np.mean(lista_idades)
print ("Media aritmética:", media)
# Out:
# Media aritmética: 29.818181818181817

# %%
#Existe a média ponderada, mas primeiro, vamos ordenar:
#Etapa de processamento dos dados
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
# Cria ou atualiza uma variável
lista_idades =[26, 30, 32, 22, 26, 35, 40,20,43,31,23,100]

# %%
# Etapa de processamento dos dados
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
#Agora, a gente pega os 2 valores do centro e tiramos a média: ou seja 61/2, que dá 30.5. Veja usando a median:
# Calcula mediana
mediana= np.median(lista_idades)
mediana
# Out:
# np.float64(30.5)

# %% [markdown]
# Voltando para a Tabela

# %%
#sim, o pandas calcula a média, mas a numpy é mais completa
#calcula a média
dados ['IDADE'].mean()
# Out:
# np.float64(31.169168453657374)

# %%
#Agora, a mediana:
#Calcula a mediana
dados ['IDADE'].median()
# Out:
# 30.0

# %%
#Agora, a moda (aquele número que aparece mais vezes):
# Etapa de processamento dos dados
dados['IDADE'].mode()
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
#Desvio padrão: vai dizer o quão disperso os nossos dados estão da média.
#Ele indica se os dados são homogêneos ou heterogêneos, quanto mais o padrão estiver mais perto de zero, mais ele é homogêneo:
dados['IDADE'].std()
# Out:
# 6.902802832143141

# %%
#funções max e min:
dados['IDADE'].min()
# Out:
# 18.0

# %%
#Etaoa de processamento dos dados
dados['IDADE'].max()
# Out:
# 54.0

# %%
#fazendo um filtro pra calcular média (média de idade de quem respondeu o formulário com o gênero feminino):
#calcula média
dados[dados['GENERO']=='Feminino']['IDADE'].mean()
# Out:
# np.float64(31.318051575931232)

# %% [markdown]
# EXERCÍCIO: 1)A média de salário das pessoas do gênero feminino é maior ou menor que as pessoas do gênero masculino(2)?

# %%
dados[dados['GENERO']=='Feminino']['SALARIO'].mean()
# Out:
# np.float64(8673.22460496614)

# %%
dados[dados['GENERO']=='Masculino']['SALARIO'].mean()
# Out:
# np.float64(11724.552688172043)

# %% [markdown]
# #Valores faltantes

# %% [markdown]
# 4.2 - Tratando Valores Faltantes - parte 1

# %% [markdown]
# Nesta aula aprendemos a tratar valores nulos! É uma etapa muito importante na análise de dados, e posteriormente em ciência de dados. Os dados nulos podem ter sido ocasionados por vários motivos: erro no preenchimento de dados, realmente falta da informação, apagamento de informações. Da mesma forma, não há um único método para tratar valores nulos. Podemos:
#
# ➡️Deletar todas as linhas com valores faltantes. É simples, mas pode resultar na perda de muitos dados, especialmente se houver muitos valores nulos.
#
# ➡️Substituir os valores faltantes pela média, ou mediana, ou moda para variáveis categóricas, ou algum valor padrão. Contudo, essa prática pode ignorar a relação entre variáveis.
#
# ➡️Uma outra possibilidade é usar um modelo de aprendizado de máquina, que considera a covariância, mas é mais trabalhoso.
#
# Nessa aula vimos que temos 3 colunas com valores nulos na nossa tabela: GENERO, IDADE e SALÁRIO.
#
# ➡️A coluna "GENERO" tem 9 valores nulos e nesse caso decidimos preencher com um valor padrão já usado na tabela: "Prefiro não informar", para isso usamos a função fillna() que pega os nulos e substitui pelo valor passado.

# %%
#Informações da tabela
#Mostra informações gerais do Dataframe
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %% [markdown]
# Trabalhando Coluna de Gênero

# %%
# Remove valores nulos da base
dados.groupby('GENERO', dropna= False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
# fillna pega os nulos e substitui pelo valor passado."prefiro nao informar "
# Preenche valores nulos
dados['GENERO'] = dados['GENERO'].fillna("Prefiro não informar")

# %%
# Remove valores nulos da base
dados.groupby('GENERO', dropna= False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# ### Trabalhando coluna de idade

# %%
# Verifica valores nulos
dados['IDADE'].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
# Etapa de processamento dos dados
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
# Verifica valores nulos
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
# Calcula média
media_17_21= dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()

# %%
# Verifica valores nulos
dados.loc[(dados['FAIXA IDADE']=='17-21') & (dados['IDADE'].isnull()),'IDADE']
# Out:
# 1925   NaN
# 2393   NaN
# 3367   NaN
# 4086   NaN
# 4177   NaN
# 4269   NaN
# Name: IDADE, dtype: float64

# %% [markdown]
# Vamos filtrar e exibir as linhas onde a 'FAIXA IDADE' é '17-21' e a 'IDADE' é nula:

# %%
# Verifica valores nulos
filtro_idade_nula_faixa = (dados['FAIXA IDADE'] == '17-21') & (dados['IDADE'].isnull())
display(dados[filtro_idade_nula_faixa])
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 1925        1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2393        2393  gbulbs9uhz9jlt33phgbulbsg77tg6wv    NaN       17-21
# 3367        3367  7nnh838dg3bhxp54swi7nnh8hmgso93p    NaN       17-21
# 4086        4086  1hvy1a0shl8q112axrop53wa0oztosc2    NaN       17-21
# 4177        4177  0qotmcuxxw222s4bs0qotne7vpcn7xxn    NaN       17-21
# 4269        4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21
#
#                     GENERO        COR/RACA/ETNIA                   PCD  \
# 1925  Prefiro não informar  Prefiro não informar  Prefiro não informar
# 2393              Feminino                Branca                   Não
# 3367              Feminino                 Parda                   Não
# 4086             Masculino                 Parda                   Não
# 4177             Masculino                Branca                   Não
# ...

# %% [markdown]
# Vamos recalcular a `media_17_21` para garantir que estamos usando o valor mais atualizado dos dados recarregados:

# %%
media_17_21 = dados[dados['FAIXA IDADE'] == '17-21']['IDADE'].mean()
print(f"A média de idade para a faixa 17-21 é: {media_17_21}")
# Out:
# A média de idade para a faixa 17-21 é: 20.205479452054796

# %% [markdown]
# Agora, vamos preencher os valores nulos na coluna 'IDADE' para a 'FAIXA IDADE' de '17-21' com essa média. Usaremos o `loc` para garantir que estamos modificando apenas as linhas corretas.

# %%
# Verifica valores nulos
dados.loc[(dados['FAIXA IDADE'] == '17-21') & (dados['IDADE'].isnull()), 'IDADE'] = media_17_21

# %% [markdown]
# Para confirmar que os valores foram preenchidos, vamos exibir novamente as linhas onde a 'FAIXA IDADE' é '17-21' e a 'IDADE' era nula. Agora, elas devem mostrar o valor da média:

# %%
# Etapa de processamento dos dados
filtro_idade_nula_faixa_preenchida = (dados['FAIXA IDADE'] == '17-21')
## Exibe as primeiras linhas da tabela
display(dados[filtro_idade_nula_faixa_preenchida].head(10)) # Mostrando algumas linhas para verificar
# Out:
#      Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 6             6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21
# 44           44  zq4itpk2kgxbgr3fsezq4imcd1fe1e0o   18.0       17-21
# 114         114  z6o09m66myb91irdniz6o09mlvet3e11   20.0       17-21
# 136         136  yzvl91qlns3pedwn7qhjyzvlzw8hsvlf   21.0       17-21
# 194         194  yjsb2rjm77dbmychoyjsbqfp0mgzgimq   21.0       17-21
# 205         205  yhfntthpl95xyc1iapyhfntth0vauh36   21.0       17-21
# 213         213  yec0fzc948zxhbu14on6yec0fmhp5ye7   20.0       17-21
# 228         228  y8vhq2nqj0y0njb29ey8v78rc26feoq8   21.0       17-21
# 246         246  y4jpyosn9xymj24z7thgy4jpyosajgar   18.0       17-21
# 256         256  y1axniksf29u32zvdhn7oiy1axniksi0   21.0       17-21
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 6    Masculino          Parda  Não
# 44   Masculino          Parda  Não
# 114  Masculino          Parda  Não
# 136   Feminino          Parda  Não
# ...

# %%
#Verifica valores nulos
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+    68
# Name: count, dtype: int64

# %%
#Etapa de processamento dos dados
dados[dados['FAIXA IDADE']=='55+']['IDADE']
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
dados[dados['FAIXA IDADE']=='55+']['NIVEL']
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %%
# Calcula média
media_geral = dados['IDADE'].mean()
media_geral
# Out:
# np.float64(31.153517220250375)

# %%
# Verifica valores nulos
dados.loc[(dados['FAIXA IDADE']=='55+') &(dados['IDADE'].isnull()),'IDADE'] = media_geral

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ### Tratando coluna salário

# %% [markdown]
# 4.2 -Tratando valores faltantes - parte 3
#
# Vamos seguir com nossa aula, agora com a coluna SALARIO✅
#
# ➡️Agora, para a coluna "SALARIO", com 577 valores nulos e sem informações na coluna de Faixa salarial, usamos a mediana para preencher, pois ela é menos afetada por valores discrepantes.
#
# Assim, tratamos todos os valores nulos na nossa tabela de forma eficiente e coerente, garantindo a integridade dos dados para análises futuras.

# %%
#verifica valores nulos
dados[dados['SALARIO'].isnull()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 12            12  zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34
# 28            28  ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24
# 34            34  zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24
# 39            39  zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34
# 63            63  zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29
# ...          ...                               ...    ...         ...
# 4242        4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29
# 4252        4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 12    Masculino         Branca  Não
# 28     Feminino          Parda  Não
# ...

# %%
#Verifica valores nulos
dados[dados['SALARIO'].isnull()]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
#calcula mediana
mediana_salario = dados['SALARIO'].median()

# %%
#verifica valores nulos
dados.loc[dados['SALARIO'].isnull(),'SALARIO'] = mediana_salario

# %% [markdown]
# ### Valores discrepantes (Outliers)

# %% [markdown]
# 4.3 - Tratando valores discrepante - outliers(parte1)
#
# Ei, Astronautas!🥰
#
# Nesta aula vimos sobre valores discrepantes ou outliers, que são valores que se destacam significativamente dos demais. Temos algumas formas de identificar esses valores, nessa aula aprendemos duas:
#
#
#
# ➡️Utilizando o desvio padrão
#
# ➡️Através da regra dos quartis.
#
#
#
# Devemos usá-las de acordo com o contexto dos nossos dados, se eles já são bem variados ou não.
#
#
#
# No exemplo que vimos da lista de idades os dados eram pouco variados e, por isso, a regra dos quartis funcionaria bem para tirarmos o outlier de 15. Confirmamos isso visualizando o boxplot desses dados com a função plt.boxplot
#
#
#
# Já com a coluna de salário da nossa tabela, por ser um campo com valores bem variados, a regra dos quartis tiraria muitos valores que não deveriam, confirmamos isso com o boxplot e também o cálculo de qual seria o limite superior e inferior dos nossos dados.
#
#
#
# limSup = Q3 + (1.5*IQR) e
#
# limInf = Q1 - (1.5*IQR)
#
#
#
# Sendo Q1 nosso quartil de 25% dos dados e Q3 nosso quartil de 75% dos dados. É como se contássemos nossos dados em uma pizza de 4 pedaços e pegássemos onde fica o corte do 1 pedaço e do 3.
#
# Para pegar os quartis usamos a função quantile e passamos o percentual que queremos em valores de 0 a 1.
#
#
#
# IQR = Q3 - Q1
#
#
#
# ⚠️considerando salários acima de 22,359 como outliers.
#
#
#
# Por isso vimos o uso do desvio padrão.
#
#
#
# ✨Cenas dos próximos capítulos✨
#
#
#
# Na próxima aula vamos dar continuidade:
#
#
#
# ➡️Definir limites
#
#
#
# Te encontro lá!🥰

# %%
#Observe que o 400 é um valor discrepante:
lista_idades = [26, 30, 32, 22, 26, 35, 400, 20, 43, 31, 23] #imagina aqui sendo 400, a media aumentou absurdamente

# %%
#calcula média
media = np.mean(lista_idades)
media
# Out:
# np.float64(62.54545454545455)

# %%
#vamos calcular o desvio padrão dessas idades:
desvio = np.std(lista_idades)
desvio
# Out:
# np.float64(106.89532997398872)

# %%
# Etapa de processamento dos dados
media + 3*desvio
# Out:
# np.float64(383.2314444674207)

# %%
# Etapa de processamento dos dados
media - 3*desvio
# Out:
# np.float64(-258.1405353765116)

# %%
# Importa biblioteca utilizada no projeto
import matplotlib.pyplot as plt

# %%
# Cria visualização gráfica
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d61f5af38c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d61f5af2a20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d61f63410a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d61f5af0920>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d61f5af2f30>],
#  'means': []}

# %% [markdown]
# Nota sobre o grafico
# A linha laranja é nossa mediana
# As bordas e nosso quartil q1 e q3
# Linha abaixo limite inferior
# Linha acima limite superior

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d61f5a222a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d61f5a22960>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d61f6ba3290>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d61f5a22f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d61f5a232c0>],
#  'means': []}

# %%
Q1 = dados ['SALARIO'].quantile (0.25) # 1/4 de 100 = 0.25
Q1
# Out:
# np.float64(4751.5)

# %%
Q3 =dados['SALARIO'].quantile(0.75)
Q3
# Out:
# np.float64(11794.5)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(7043.0)

# %%
lim_superior = Q3 + (1.5* IQR)
lim_superior
# Out:
# np.float64(22359.0)

# %%
lim_inferior = Q1 - (1.5*IQR)
lim_inferior
# Out:
# np.float64(-5813.0)

# %%
dados['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %%
media_salario = dados['SALARIO'].mean()
media_salario
# Out:
# np.float64(10517.53348162023)

# %%
desvio_salario = dados['SALARIO'].std()
desvio_salario
# Out:
# 18096.210989118474

# %%
limite_superior = media_salario + (3* desvio_salario)
limite_superior
# Out:
# np.float64(64806.16644897565)

# %% [markdown]
# 4.3 - Tratando valores discrepantes outliers - parte 2

# %% [markdown]
# Nesta aula, a análise de contexto foi crucial para definir limites🖥️
#
# Calculamos a média e o desvio padrão dos salários com mean() e std(), usando media_salario e desvio_salario, respectivamente. Definimos o limite superior como media_salario + (3*desvio_salario), resultando em 64,806.16, um valor adequado para outliers.
#
# Após identificar os outliers, decidimos se os removeríamos ou substituiríamos. No nosso caso, verificamos a faixa salarial e substituímos salários discrepantes pela média da faixa correspondente, garantindo coerência.✅

# %%
dados[dados['SALARIO']> limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês              19
# de R$ 30.001/mês a R$ 40.000/mês     3
# Name: count, dtype: int64

# %%
media_30_40 = dados[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês')& (dados['SALARIO']<limite_superior)]['SALARIO'].mean()

# %%
dados.loc[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês')& (dados['SALARIO']>limite_superior),'SALARIO']=media_30_40

# %%
dados[dados['SALARIO']> limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %%
media_40 = dados[(dados['FAIXA SALARIAL'] == 'Acima de R$ 40.001/mês') & (dados['SALARIO'] < limite_superior)]['SALARIO'].mean()
media_40
# Out:
# np.float64(53127.846153846156)

# %%
dados.loc[(dados['FAIXA SALARIAL'] == 'Acima de R$ 40.001/mês') & (dados['SALARIO']> limite_superior),'SALARIO'] = media_40

# %%
dados[dados['SALARIO']> limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d61f5698980>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d61f5698f50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d61f56986e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d61f56995b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d61f5699880>],
#  'means': []}

# %% [markdown]
# #Distribuição amostral e intervalo de confiança

# %% [markdown]
# 4.4 - Intervalo de confiança e distribuiçãp amostral

# %% [markdown]
# Nesta aula, utilizamos a coluna de ‘SALARIO’ da nossa tabela como nossa amostra para entender melhor os conceitos de intervalo de confiança e distribuição amostral. Realizamos os seguintes passos:
#
# ➡️Média Amostral:
#
# Calculamos a média dos salários na nossa amostra. Isso nos dá uma estimativa do salário médio na população.
#
# ➡️Desvio Padrão Amostral:
#
# Calculamos o desvio padrão dos salários na nossa amostra. O desvio padrão nos mostra o quanto os salários variam em relação à média amostral.
#
# ➡️Erro Padrão:
#
# O erro padrão é calculado dividindo o desvio padrão da amostra pela raiz quadrada do tamanho da amostra. Ele nos ajuda a entender a precisão da nossa média amostral como uma estimativa da média populacional.
#
# ➡️Intervalo de Confiança de 95%:
#
# Calculamos o intervalo de confiança para um nível de 95% de confiança. Isso significa que, se repetíssemos esse processo muitas vezes, 95% das vezes o intervalo conteria a verdadeira média populacional.
#
# Nosso intervalo de confiança calculado foi de 9618 a 10105. O intervalo de confiança de 95% entre 9618 e 10105 significa que estamos 95% confiantes de que a verdadeira média salarial da população está entre 9618 e 10105. Em outras palavras, se coletássemos muitas amostras diferentes e calculássemos intervalos de confiança para cada uma, esperamos que 95% desses intervalos contenham a verdadeira média salarial.
#
# ➡️Importância do Intervalo de Confiança:
#
# Precisão: O intervalo de confiança nos dá uma faixa dentro da qual acreditamos que a média populacional se encontra, tornando nossa estimativa mais informativa do que uma única média amostral.
#
# Incerteza: Reconhece a incerteza inerente à amostragem e nos dá uma ideia de quanto essa incerteza pode ser.
#
# Essa aula destacou como podemos usar conceitos estatísticos para fazer estimativas mais confiáveis e informadas sobre uma população, mesmo quando trabalhamos apenas com uma amostra. Entender e calcular intervalos de confiança é uma habilidade crucial na análise de dados, permitindo-nos tomar decisões baseadas em dados com maior certeza e precisão.🧐

# %%
# Cria ou atualiza uma variável
salarios = dados['SALARIO'] # nosso salario é uma amostra

# %%
# Etapa de processamento dos dados
salarios
# Out:
# 0       11194.0
# 1        4695.0
# 2       14202.0
# 3       15463.0
# 4        7733.0
#          ...
# 4266     4329.0
# 4267     3758.0
# 4268    19607.0
# 4269      989.0
# 4270     3079.0
# Name: SALARIO, Length: 4271, dtype: float64

# %%
# Calcula média
media_amostral = np.mean(salarios)
media_amostral
# Out:
# np.float64(9904.390109813306)

# %%
# Cria ou atualiza uma variável
desvio_amostral = np.std(salarios)
desvio_amostral
# Out:
# 8306.104872579343

# %%
# Cria ou atualiza uma variável
nivel_confianca = 0.95

# %%
# Cria ou atualiza uma variável
tamanho_amostra = len(salarios)
tamanho_amostra
# Out:
# 4271

# %%
#Importa função ou módulo específico
from scipy import stats

# %%
# Cria ou atualiza uma variável
erro_padrao = stats.sem(salarios)
# Etapa de processamento dos dados
erro_padrao
# Out:
# np.float64(127.11109872023638)

# %%
# Seleciona dados por rótulo
intervalo_confianca = stats.t.interval(nivel_confianca,tamanho_amostra-1,loc=media_amostral,scale=erro_padrao)
intervalo_confianca
# Out:
# (np.float64(9655.186295869078), np.float64(10153.593923757535))

# %% [markdown]
# #Featuring Engineering

# %% [markdown]
# 4.5 - Featuring engineering: criando novas variáveis para facilitar a análise - parte 1
#
# Nesta aula, abordamos o conceito de feature engineering, que é o processo de criar novas variáveis a partir dos dados existentes para melhorar a análise e a modelagem😍
#
# ➡️Criamos a coluna "NOVO_NIVEL":
#
# Criamos uma função chamada preencher_nivel que atribui o valor "Pessoa Gestora" se a coluna "GESTOR" for igual a 1; caso contrário, mantém o valor da coluna "NIVEL". Adicionamos essa nova coluna ao nosso DataFrame para diferenciar claramente entre gestores e outros níveis.
#
# ➡️Conversão de Variáveis Categóricas:
#
# Utilizamos pd.get_dummies para transformar a coluna "NIVEL" em variáveis dummy. Isso é útil para modelos de machine learning que requerem dados numéricos.
#
# ➡️Criação da Coluna "GERAÇÃO":
#
# Desenvolvemos uma função chamada determinar_geracao para categorizar os indivíduos em diferentes gerações (Geração X, Millennial, Geração Z) com base na idade. Adicionamos essa nova coluna ao DataFrame, permitindo análises segmentadas por faixa etária.

# %%
def preencher_nível(gestor,nivel):
  if gestor==1:
    return "Pessoa Gestora"
  else:
    return nivel

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
# Cria ou atualiza uma variável
dados['NOVO_NIVEL'] = dados.apply(lambda x: preencher_nível(x['GESTOR?'], x['NIVEL']), axis=1)

# %%
dados['NOVO_NIVEL'].value_counts()
# Out:
# NOVO_NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados['NOVO_NIVEL']. value_counts()
# Out:
# NOVO_NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados['NIVEL']
# Out:
# 0       Júnior
# 1          NaN
# 2        Pleno
# 3       Sênior
# 4        Pleno
#          ...
# 4266     Pleno
# 4267     Pleno
# 4268       NaN
# 4269    Júnior
# 4270    Júnior
# Name: NIVEL, Length: 4271, dtype: object

# %%
# Cria ou atualiza uma variável
dados= pd.get_dummies(dados,columns=['NIVEL'])

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
def determinar_geracao(idade):
  if 39 < idade <= 58:
    return "Geração x"
  elif 29 < idade <=39:
    return 'Millenial'
  elif 13< idade <= 29:
      return "Geração z"
  else:
    return "Outra geração"

# %%
# Cria ou atualiza uma variável
dados["GERACAO"] = dados['IDADE'].apply(determinar_geracao)

# %%
# Conta frequência dos valores
dados['GERACAO'].value_counts()
# Out:
# GERACAO
# Geração z    1999
# Millenial    1761
# Geração x     511
# Name: count, dtype: int64

# %% [markdown]
# 4.5 - Featuring engineering: criando novas variáveis para facilitar a análise (parte 2)
# Dando continuidade🖥️
#
# ➡️Identificação de Intenção de Mudança de Emprego:
#
# Criamos duas novas colunas, "EM_BUSCA" e "ABERTO_OPORTUNIDADES", a partir das respostas à pergunta sobre a intenção de mudar de emprego nos próximos 6 meses. Utilizamos funções de string para identificar se os respondentes estão "em busca" ou "abertos" a novas oportunidades, facilitando a análise do mercado de trabalho.

# %%
# Cria ou atualiza uma variável
dados2 = pd.read_excel('/content/drive/MyDrive/Materiais e arquivos/Materiais importantes /Curso Programaria /Cópia de Planilha_Aula_parte2.xlsx')

# %%
# Exibe as primeiras linhas da tabela
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
# ...

# %%
# Realiza junção entre tabelas
dados = dados.merge(dados2,on='ID',how='left')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
# Conta frequência dos valores
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
# Aplica operação de texto na coluna
dados['EM_BUSCA'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('em busca', case=False)

# %%
# Conta frequência dos valores
dados['EM_BUSCA'].value_counts()
# Out:
# EM_BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
# Aplica operação de texto na coluna
dados['ABERTO_OPORTUNIDADE'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('aberto', case=False)

# %%
# Conta frequência dos valores
dados['ABERTO_OPORTUNIDADE'].value_counts()
# Out:
# ABERTO_OPORTUNIDADE
# False    2342
# True     1354
# Name: count, dtype: int64

# %%
#Exercício: Com base no que aprendemos nas aulas de Featuring engineering, crie uma nova coluna de Etnia - brancas, não branca e outras:
dados['COR/RACA/ETNIA'].value_counts()
# Out:
# COR/RACA/ETNIA
# Branca                  2746
# Parda                   1054
# Preta                    291
# Amarela                  128
# Prefiro não informar      26
# Outra                     17
# Indígena                  11
# Name: count, dtype: int64

# %%
#Aplica operação de texto na coluna
dados['RACA_INDIGENA'] = dados['COR/RACA/ETNIA'].str.contains('Indígena', case=False)

# %%
#Conta frequência dos valores
dados['RACA_INDIGENA'].value_counts()
# Out:
# RACA_INDIGENA
# False    4262
# True       11
# Name: count, dtype: int64

# %%
dados['COR_PRETA'] = dados['COR/RACA/ETNIA'].str.contains('Preta', case=False)
dados['COR_PRETA'].value_counts()
# Out:
# COR_PRETA
# False    3982
# True      291
# Name: count, dtype: int64

# %%
dados['COR_PARDA'] = dados['COR/RACA/ETNIA'].str.contains('Parda', case=False)
dados['COR_PARDA'].value_counts()
# Out:
# COR_PARDA
# False    3219
# True     1054
# Name: count, dtype: int64

# %%
dados['COR_AMARELA'] = dados['COR/RACA/ETNIA'].str.contains('Amarela', case=False)
dados['COR_AMARELA'].value_counts()
# Out:
# COR_AMARELA
# False    4145
# True      128
# Name: count, dtype: int64

# %%
dados['OUTRA_COR_RACA'] = dados['COR/RACA/ETNIA'].str.contains('Outra', case=False)
dados['OUTRA_COR_RACA'].value_counts()
# Out:
# OUTRA_COR_RACA
# False    4256
# True       17
# Name: count, dtype: int64

# %%
dados['SEM_INFORMAR_COR'] = dados['COR/RACA/ETNIA'].str.contains('Prefiro não informar', case=False)
dados['SEM_INFORMAR_COR'].value_counts()
# Out:
# SEM_INFORMAR_COR
# False    4247
# True       26
# Name: count, dtype: int64

# %% [markdown]
# #Correlação

# %% [markdown]
# 4.6 - Correlação, diferentes funções para dados discretos e contínuos

# %% [markdown]
# A correlação nos diz se e como duas variáveis estão relacionadas🤔 Existem dois tipos principais de correlação: positiva e negativa.
#
# ➡️A correlação positiva ocorre quando duas variáveis aumentam juntas.
#
# Por exemplo, quanto mais um aluno estuda, maior é seu desempenho acadêmico.
#
# ➡️Já a correlação negativa acontecia quando uma variável aumenta enquanto a outra diminui.
#
# Por exemplo, quanto mais tempo um aluno passa assistindo TV, menor é seu desempenho acadêmico.
#
# 📌A função de correlação mais usada é a de Pearson, que varia de -1 a 1. Um valor próximo de 1 indica uma forte correlação positiva, próximo de -1 indica uma forte correlação negativa, e próximo de 0 indica que não há uma relação linear.
#
# Por exemplo, ao calcular a correlação entre horas de estudo e desempenho acadêmico, um coeficiente de 0.8 indica uma correlação positiva forte.
#
# No nosso caso, calculamos a correlação entre idade e salário usando a função corr do pandas. Obtivemos um valor de 0.29, indicando uma correlação positiva, mas não muito forte.
#
# 📌Entender a correlação ajuda a evitar suposições.
#
# Por exemplo, esperávamos que a idade fosse um fator importante para o aumento salarial, mas nossos dados mostram que, apesar de ter uma relação, não é tão forte. Para identificar correlações em tabelas com muitas colunas de valores contínuos, utilizamos mapas de calor.
#
# Um exemplo de mapa de calor permite visualizar rapidamente a correlação entre variáveis contínuas, com cores indicando a força da correlação.
#
# 📌Também calculamos a correlação entre variáveis discretas usando o coeficiente de Cramér.
#
# Criamos uma função cramer_coeficiente para calcular este coeficiente, utilizando a tabela cruzada gerada com crosstab do pandas e a função chi2_contingency da biblioteca stats.
#
# Aplicamos essa função para verificar a relação entre cor/raça/etnia e nível de ensino, obtendo um coeficiente de 0.044, indicando quase nenhuma relação. Este resultado sugere que, na nossa amostra, etnias diferentes têm níveis de ensino semelhantes, possivelmente devido ao contexto da área de TI, onde a maioria já tem algum tipo de formação.

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
# Calcula correlação entre variáveis
correlacao_continua = dados['IDADE'].corr(dados['SALARIO']) #correlação positiva, porem proximo do zero
correlacao_continua
# Out:
# np.float64(0.2902441968622099)

# %%
# Importa função ou módulo específico
from scipy.stats import chi2_contingency

# %%
# Etapa de processamento dos dados
def cramer_coefieciente(coluna1,coluna2):
    tabela_cruzada= np.array(pd.crosstab(coluna1,coluna2))
    chi2 =chi2_contingency(tabela_cruzada)[0]
    soma =np.sum(tabela_cruzada)
    mini = min(tabela_cruzada.shape) -1
    cramer = np.sqrt(chi2/(soma*mini))
    return cramer

# %%
cramer_coefieciente(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
# Out:
# np.float64(0.04499106580480143)

# %%
tabela_cruzada= pd.crosstab(dados['COR/RACA/ETNIA'],dados['NIVEL DE ENSINO'])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# ...

# %%
np.array(tabela_cruzada)
# Out:
# array([[  7,  15,  50,  14,   2,   0,  40],
#        [127, 365, 999, 355,  65,   8, 827],
#        [  0,   2,   4,   2,   0,   0,   3],
#        [  0,   0,   6,   3,   1,   0,   7],
#        [ 50, 178, 333, 113,  33,   3, 344],
#        [  1,   2,  14,   1,   0,   1,   7],
#        [  6,  51, 104,  33,   9,   0,  88]])

# %% [markdown]
# MOD4, 4.7 - Resumo da ópera: Nesta aula nós recapitulamos todo o conteúdo que cobrimos neste módulo do curso de análise de dados🖥️
#
# Começamos o módulo falando sobre os principais conceitos de estatística, aplicando-os na tabela de dados que estamos trabalhando neste curso.
#
# ✅Em seguida nos aprofundamos no tratamento de valores faltantes e outliers. Aprendemos técnicas para identificar e corrigir dados incompletos e atípicos, garantindo que nossas análises sejam precisas e robustas. Também abordamos a importância de calcular intervalos de confiança e entender a distribuição amostral, permitindo-nos fazer inferências sobre a população com base em amostras.
#
# ✅Uma parte essencial do nosso aprendizado foi o feature engineering, onde criamos novas variáveis para enriquecer nossos dados e facilitar a análise. Transformamos dados brutos em informações valiosas, o que é crucial para melhorar a performance dos modelos preditivos. Além disso, exploramos a correlação para entender as relações entre variáveis, uma habilidade vital para identificar padrões e insights nos dados.
#
# ✅Nesta aula de resumo, também enfatizamos a importância de manter um código bem documentado e organizado. É fundamental que vocês coloquem comentários no código para torná-lo mais compreensível, organizem seus notebooks e sigam as práticas de clean code. Isso não só facilita a revisão e o compartilhamento do trabalho, mas também garante que vocês possam retornar ao código no futuro e entendê-lo facilmente.
#
# Chegamos a um ponto importante do curso, onde consolidamos uma grande quantidade de conhecimento. Continuem praticando, revisando os conceitos e aplicando essas boas práticas de codificação.

# %%
import os

directory_path = '/content/drive/MyDrive/Materiais e arquivos/Materiais importantes /Curso Programaria /Arquivos'
os.makedirs(directory_path, exist_ok=True)
dados.to_csv(os.path.join(directory_path, 'analise_dados.csv'), index = False)

# %% [markdown]
# #Conectando SQL  com pandas ![819c217d2244f8f3243f1c44e72c6d0e.gif](data:image/gif;base64,...)
#
# :

# %% [markdown]
# Nossa, gosto muito quando conseguimos juntar coisas que aprendemos, não é mesmo?🤩
#
# Nas próximas aulas, juntamos o que vimos de banco de dados para puxar nossos dados lá pra nossa tabela do pandas, aprendemos a usar o comando IN e a filtrar no banco utilizando parâmetros. Fizemos o merge com a nossa tabela e ainda revisitamos a aula de correlação! Ufa! Intensas😂
#
# Vamos iniciar o primeiro passo?
#
# ➡️Para fazer a  conexão com o banco de dados SQLite, utilizamos a biblioteca sqlite3, então fizemos o import dela: import sqlite3
#
# ➡️A função connect() do sqlite3 foi utilizada para estabelecer a conexão, passando o caminho do arquivo do banco de dados como parâmetro.

# %%
import sqlite3

# %%
import sqlite3
conexao = sqlite3.connect('/content/drive/MyDrive/Materiais e arquivos/Materiais importantes /Curso Programaria /Arquivos /Status_brasil')

# %%
query = "SELECT* FROM Municipios_Brasileiros Where Cidade Like 'Maragogi';"

# %%
pd.read_sql(query, con= conexao)
# Out:
#      Cidade Estado    Regiao  municipio_ID
# 0  Maragogi     AL  Nordeste            72

# %%
#Agora, Vamos acompanhar a média da renda por estado:
#Copie o JOIN que fizemos no DBEaver:
query = '''SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.Renda)
        FROM Municipios_Brasileiros
        INNER JOIN Municipio_Status ON Municipios_Brasileiros.Municipio_ID = Municipio_Status.Municipio_ID
        GROUP BY Municipios_Brasileiros.Estado;'''

# %% [markdown]
# 5.6

# %%
#Execute a consulta novamente:
pd.read_sql(query, con=conexao)
# Out:
#      Cidade Estado    Regiao  municipio_ID
# 0  Maragogi     AL  Nordeste            72

# %%
#Agora vamos fazer a leitura do nosso arquivo usando pandas.
#Adicione dentro das aspas o caminho do arquivo que já havíamos salvado em aulas anteriores:
dados = pd.read_csv('/content/drive/MyDrive/Materiais e arquivos/Materiais importantes /Curso Programaria /Arquivos/analise_dados.csv')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
#Deixe em formato de lista as informações:
lista_estados = list(dados['UF ONDE MORA'].unique())

# %%
#Volte na query que realizamos anteriormente, adicione WHERE Municipios_Brasileiros.Estado IN ({})
#Em seguida, adicione .format(', '.join(['?' for _ in lista_estados])) ao final do texto:

query = '''SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.Renda)
        FROM Municipios_Brasileiros
        INNER JOIN Municipio_Status ON Municipios_Brasileiros.Municipio_ID = Municipio_Status.Municipio_ID
        WHERE Municipios_Brasileiros.Estado IN ({})
        GROUP BY Municipios_Brasileiros.Estado;'''.format(', '.join(['?' for _ in lista_estados]))

# %%
estados_renda = pd.read_sql(query, con = conexao, params = lista_estados)
estados_renda.rename(columns={'AVG(Municipio_Status.Renda)': 'Renda_Media_Estado'}, inplace=True)

# %%
#Mude o nome da coluna:
dados.rename(columns = {'UF ONDE MORA': 'Estado'}, inplace=True)

# %%
dados = dados.merge(estados_renda, on='Estado', how='left')

# %%
#Faça a correlação:
correlacao_renda_salario = dados['SALARIO'].corr(dados['Renda_Media_Estado'])
correlacao_renda_salario
# Out:
# np.float64(0.1246751994916647)

# %% [markdown]
# 5.6 - Conectando SQL com o pandas - parte 3

# %%
a ='batata'

# %%
print('eu gosto de{}'.format(a))
# Out:
# eu gosto debatata

# %%
a =['batata','tomate','alface']

# %%
print('Eu gosto de {},{} e {}'.format(a[0],a[1], a[2]))
# Out:
# Eu gosto de batata,tomate e alface

# %%
print('Eu gosto de {}'.format(','.join(a)))
# Out:
# Eu gosto de batata,tomate,alface

# %% [markdown]
# #Visualização de Dados

# %% [markdown]
# #Visualização de dados em Python - Parte 1

# %% [markdown]
# Ei, Astronautas💜 A aula explorou a arte e a ciência da criação de gráficos informativos e visualmente atraentes utilizando o Python. Desvendamos os elementos essenciais que tornam um gráfico eficaz, desde a escolha do tipo ideal até a seleção da biblioteca e do estilo adequado. Enfatizamos a importância da comunicação clara e concisa de insights por meio de visualizações bem elaboradas.👀
#
# ➡️A primeira biblioteca que vimos foi a Matplotlib, ela é a mais clássica em python para visualização. Permite a criação de diversos tipos de gráficos, incluindo linhas, barras, pizza, dispersão e violinos. Integra-se com outras bibliotecas de análise de dados, como NumPy e Pandas.
#
# Com ela fizemos o gráfico de distribuição de gênero:
#
# plt.figure();
#
# plt.bar(genero_counts.index, genero_counts.values);
#
# plt.show()
#
# ➡️Vimos como adicionar título ao gráfico e aos eixos com os comandos: plt.xlabel, plt.ylabel e plt.title. O que deixou a nossa visualização bem mais informativa. Com isso vimos de forma clara e rápida que mais homens responderam à pesquisa do que mulheres, o que nos faz inferir que existem mais homens na área de dados. Conseguimos com esse gráfico cumprir as 2 regras dos 5 segundos, criando um gráfico com Clareza e Eficiência.
#
# ➡️Também aprendemos a gerar o mesmo gráfico com a biblioteca seaborn, utilizando a função countplot. A seaborn é baseada na matplotlib, porém normalmente conseguiremos gerar com ela gráficos atrelados ao pandas de forma mais rápida e com menos linhas, além de ter mais opções pré-definidas de personalização.
#
# ➡️Também fizemos um gráfico de linhas e um scatterplot para visualizar a relação entre salário e idade. Apesar de que olhando pela média dos salários pelo gráfico de linha eles parecem crescer com a idade, quando olhando a distribuição dos pontos pelo scatterplot percebemos que na verdade depois dos 25 a maioria das pessoas recebe mais ou menos na mesma faixa salarial. Isso nos mostrou que às vezes vale olhar os mesmos dados de diferentes óticas para obtermos uma conclusão mais correta.

# %%
import pandas as pd

# %%
dados=pd.read_csv('/content/drive/MyDrive/Materiais e arquivos/Materiais importantes /Curso Programaria /Arquivos/analise_dados.csv')

# %%
dados.head()
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
# ...

# %%
genero_counts = dados['GENERO'].value_counts()

# %%
genero_counts
# Out:
# GENERO
# Masculino               3194
# Feminino                1058
# Prefiro não informar      21
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
# Adicionei a cor e um rótulo para a legenda funcionar
plt.bar(height=genero_counts.values, x=genero_counts.index, color=['#3498db', '#e74c3c', '#95a5a6'], label='Contagem')
plt.title('Quantidade de pessoas por gênero na área de Dados')
plt.xlabel('Gênero')
plt.ylabel('Quantidade')
plt.show()

# %%
#Uma outra forma de fazermos esse mesmo gráfico, é utilizando a biblioteca Seaborn:
import seaborn as sns

# %%
plt.figure()
sns.countplot(data=dados, x='GENERO', palette='pastel')
plt.title('Quantidade de pessoas por gênero na área de Dados')
plt.xlabel('Gênero')
plt.ylabel('Quantidade')
plt.show()
# Out:
# /tmp/ipykernel_3499/3175647684.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dados, x='GENERO', palette='pastel')

# %% [markdown]
# #Visualização de dados em Python - Parte 2

# %% [markdown]
# E para criar esses gráficos, além das libs matplotlib e seaborn, também aprendemos a usar a plotly, uma biblioteca de visualização muito agradável por ser interativa. Vimos nela as funções: px.line - para gráficos de linha e px.scatter - para scatterplot.
#
# ➡️Para encerrar, lembre-se dos pontos importantes que vimos na aula:
#
# Escolha o gráfico ideal para cada situação e público.
#
# Utilize cores e estilos claros, concisos e estéticamente agradáveis.
#
# Títulos, rótulos e legendas informativas facilitam a compreensão.
#
# A combinação de ferramentas e boas práticas de design resulta em gráficos informativos e inspiradores.
#
# Explore os recursos avançados das bibliotecas Matplotlib, Seaborn e Plotly.
#
# Continue explorando e aprendendo sobre visualização de dados para se tornar um especialista em comunicação de informações.

# %%
salario_por_idade = dados.groupby("IDADE")['SALARIO'].mean ()

# %%
salario_por_idade
# Out:
# IDADE
# 18.000000     4230.307692
# 19.000000     4519.590909
# 20.000000     5004.272727
# 20.205479     3536.000000
# 21.000000     4578.737179
# 22.000000     4394.689815
# 23.000000     5602.406897
# 24.000000     6151.622449
# 25.000000     7616.392336
# 26.000000     7700.071174
# 27.000000     8237.429766
# 28.000000     9737.938144
# 29.000000     9554.853147
# 30.000000    10316.412686
# 31.000000    10021.462609
# 31.153517     9646.330882
# 32.000000    10843.197778
# 33.000000    11592.718590
# 34.000000    12294.640212
# 35.000000    12435.845105
# 36.000000    12267.966533
# 37.000000    12613.528357
# 38.000000    13802.724874
# 39.000000    13309.082898
# 40.000000    15028.032721
# 41.000000    13578.880952
# 42.000000    11801.037037
# 43.000000    14349.732278
# 44.000000    14665.770147
# 45.000000    16103.431520
# 46.000000    11913.709677
# 47.000000    11156.031250
# 48.000000    12249.714286
# 49.000000    14556.000000
# 50.000000    15740.010181
# ...

# %%
plt.figure()
plt.plot(salario_por_idade.index, salario_por_idade.values, marker='o',linestyle='--')
plt.xlabel('Idade')
plt.ylabel('Média de salário')
plt.title('Média de salário por idade')
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# %%
fig = px.line(salario_por_idade.reset_index(), x='IDADE', y='SALARIO', title='Média de salário por idade', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(15,5))
plt.scatter(dados['IDADE'],dados['SALARIO'], alpha= 0.5)
plt.xlabel('Idade')
plt.ylabel('Salário')
plt.title('Dispersão de salário por idade')
plt.grid(True)
plt.show()

# %%
fig=px.scatter(dados, x ='IDADE', y='SALARIO', title='Dispersão de salário por idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
